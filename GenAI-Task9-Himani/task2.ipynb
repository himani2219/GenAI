# %%
import numpy as np

# %%
A = np.array([10, 20, 30, 40])
B = np.array([1, 2, 3, 4])
print(f"A + B = {A + B}")
print(f"A - B = {A - B}")
print(f"A * B = {A * B}")
print(f"A / B = {A / B}")
print(f"A ** 2 = {A ** 2}")
# Out:
# A + B = [11 22 33 44]
# A - B = [ 9 18 27 36]
# A * B = [ 10  40  90 160]
# A / B = [10. 10. 10. 10.]
# A ** 2 = [ 100  400  900 1600]
