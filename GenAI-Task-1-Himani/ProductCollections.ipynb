# %% [markdown]
# 1. list named products containing atleast 6 products

# %%
products = ['keyboard', 'monitor','laptop', 'mouse', 'speaker', 'keypad']
print(products)
# Out:
# ['keyboard', 'monitor', 'laptop', 'mouse', 'speaker', 'keypad']

# %% [markdown]
# 2. create a tuple sample product

# %%
sample_product = ('keyboard', 2000, 'electronics')

# %% [markdown]
# 3. print 2nd and last product from products list

# %%
print(f'the second product is {products[1]} and the last product is {products[-1]}')
# Out:
# the second product is monitor and the last product is keypad

# %% [markdown]
# 4. append two new products and print list

# %%
products.append('headphones')
products.append('keypad')
print(products)
# Out:
# ['keyboard', 'monitor', 'laptop', 'mouse', 'speaker', 'keypad', 'headphones', 'keypad']

# %% [markdown]
# 5. convert sample product into a list, change price and convert back to tuple

# %%
sample_list = list(sample_product)
sample_list[1] = 3000
sample_product = tuple(sample_list)
sample_product
# Out:
# ('keyboard', 3000, 'electronics')
