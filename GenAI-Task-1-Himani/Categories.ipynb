# %% [markdown]
# 1. create categories from category list

# %%
product_list = ['pen', 'mouse', 'tshirt', 'keyboard', 'sharpener']
category_list = ['stationary', 'electronics', 'clothing', 'electronics', 'stationary']
categories = set(category_list)
categories
# Out:
# {'clothing', 'electronics', 'stationary'}

# %% [markdown]
# 2. show that duplicates are ignored

# %%
categories.add('clothing')
categories
# Out:
# {'clothing', 'electronics', 'stationary'}

# %% [markdown]
# 3. how to check if a category exists

# %%
print('electronics' in categories)
# Out:
# True
